# %% [markdown]
# # Udemy data Analysis
# 유데미 데이터를 이용한 파이썬 데이터 분석
#
# **분석자**
# - 201904128 홍윤기
# - 201904065 오세현

# %% [markdown]
# # 목차
# ---
# # 1. 서론
#
# # 2. 데이터 전처리
#  > ## 1.1 데이터 정보 읽기
#  > ## 1.2 데이터 메모리 최적화
#
# # 3. 데이터 분석
# > ## 추가 예정
# ...
#
# # 4. 데이터 시각화
#
# # 5. 결론

# %% [markdown]
# # 1. 서론
# 최근 코로나 19 사태 후 대면 교육이 어려워 지고 온라인 교육 시장(비대면, 디지털 강의)이 성장하고 있는 추세이다. <br>
# 이러한 현상으로 교육, 자기계발 등 다양한 온라인 과목이 생겨났다. 수강자는 다양한 주제 중 실용적인 과목을 듣고 싶어할 것이며, 코스 제공자는 현 트랜드를 분석하여, 많은 수강자를 모으기를 원할 것이다.
# 그렇기에 과목 중 인기 있는 주제 및 코스(강좌) 가격을 파악하고 최적화하는 등 다양한 방향으로 분석 한다면 수강자와 코스 제공자에게 도움이 될 것이다. <br>
# <br>
# 이번 분석에서는 Kaggle에서 제공하는 Udemy 코스 데이터 셋을 활용하여 비즈니스 금융, 그래픽 디자인, 음악 악기, 웹 디자인 등 4가지 주제에 대해서 분석하고 현 트랜드를 파악하고자 한다.
#
# 우리 조는 아래와 같이 분석하고자 한다.
# 1. 주제(subject), 연도별 트랜드 파악 및 그에 따른 가격, 구독자 수 영향
# 2. 강좌의 level 별 가격 측정
# 3. 코스 가격과 수강자, 제공자 간 등의 관계를 고려한 수익 예측
# 4. 추가 예정

# %% [markdown]
# # 2. 데이터 전처리
# ---
# ## 2.1 데이터 정보 읽기
# - row, column 확인
# <br>
# 데이터 전처리를 위해 데이터 정보를 읽어 올 것이다.

# %%
# 데이터 분석에 필요한 라이브러리 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from datetime import datetime # datetime을 정렬하기위함

# %%
'''
# 데이터 참고 출처
@misc{willden,
url={http://theconceptcenter.com/simple-research-study-udemy-courses/},
journal={Concept Center},
author={Willden, Chase}}
'''
# Out:
# '\n# 데이터 참고 출처\n@misc{willden,\nurl={http://theconceptcenter.com/simple-research-study-udemy-courses/},\njournal={Concept Center},\nauthor={Willden, Chase}}\n'

# %%
# 분석할 데이터 읽어오고 보여주기
course = pd.read_csv('data/udemy_courses.csv')
course
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# 1         https://www.udemy.com/goods-and-services-tax/     True     75
# 2     https://www.udemy.com/financial-modeling-for-b...     True     45
# 3     https://www.udemy.com/complete-excel-finance-c...     True     95
# 4     https://www.udemy.com/how-to-maximize-your-pro...     True    200
# ...                                                 ...      ...    ...
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 0                2147           23            51          All Levels
# 1                2792          923           274          All Levels
# 2                2174           74            51  Intermediate Level
# 3                2451           11            36          All Levels
# 4                1276           45            26  Intermediate Level
# ...               ...          ...           ...                 ...
# 3673             1040           14            21          All Levels
# 3674              306            3            42      Beginner Level
# 3675              513          169            48          All Levels
# 3676              300           31            38          All Levels
# 3677              901           36            20      Beginner Level
#
#       content_duration   published_timestamp           subject
# 0                  1.5  2017-01-18T20:58:58Z  Business Finance
# 1                 39.0  2017-03-09T16:34:20Z  Business Finance
# 2                  2.5  2016-12-19T19:26:30Z  Business Finance
# 3                  3.0  2017-05-30T20:07:24Z  Business Finance
# 4                  2.0  2016-12-13T14:57:18Z  Business Finance
# ...                ...                   ...               ...
# 3673               2.0  2016-06-14T17:36:46Z   Web Development
# 3674               3.5  2017-03-10T22:24:30Z   Web Development
# 3675               3.5  2015-12-30T16:41:42Z   Web Development
# 3676               3.0  2016-08-11T19:06:15Z   Web Development
# 3677               2.0  2014-09-28T19:51:11Z   Web Development
#
# [3678 rows x 12 columns]

# %%
# colums 종류 확인
course.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# 기초 통계값(수치형) 분석
# 혹시 몰라서.. count: column 갯수 / mean: column 평균 / std: column 표준편차
course.describe().T
# Out:
#                    count           mean            std     min       25%  \
# course_id         3678.0  675971.963295  343273.156040  8324.0  407692.5
# price             3678.0      66.049483      61.005755     0.0      20.0
# num_subscribers   3678.0    3197.150625    9504.117010     0.0     111.0
# num_reviews       3678.0     156.259108     935.452044     0.0       4.0
# num_lectures      3678.0      40.108755      50.383346     0.0      15.0
# content_duration  3678.0       4.094517       6.053840     0.0       1.0
#
#                        50%        75%        max
# course_id         687917.0  961355.50  1282064.0
# price                 45.0      95.00      200.0
# num_subscribers      911.5    2546.00   268923.0
# num_reviews           18.0      67.00    27445.0
# num_lectures          25.0      45.75      779.0
# content_duration       2.0       4.50       78.5

# %% [markdown]
# ## 2.2 데이터 메모리 최적화
# 데이터 메모리 용량을 줄이고 처리 속도 향상
# ### 현재 데이터의 columns 목록
#
# - **course_id:** course(강좌) 고유 id
# - **course_title:** course의 제목
# - **url:** 해당 course url(링크)
# - **is_paid:** course 유료 무료 차이
# - **price:** course 가격
# - **num_subscribers:** 해당 course 구독자 수
# - **num_reviews:** 해당 course 리뷰 수
# - **num_lectures:** course가 포함하고 있는 수업(영상) 수
# - **level:** course 난이도
# - **content_duration:** coures 모든 수업(영상) 시간
# - **published_timestamp:** course 제공 날짜
# - **subject:** course 분야

# %%
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
# 데이터 타입 크기 확인하는 방법 
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
# 각 칼럼별 총 메모리 계산
before_musage = course.memory_usage(deep=True).sum()

# %%
# 수치형 데이터 타입 변경
course = course.astype({'course_id' : np.int32, 
             'price' : np.int16, 
             'num_subscribers' : np.int32, 
             'num_reviews' : np.int16, 
             'num_lectures' : np.int16,
             'content_duration' : np.float16
            })

# %%
course.describe().T
# Out:
#                    count           mean            std     min       25%  \
# course_id         3678.0  675971.963295  343273.156040  8324.0  407692.5
# price             3678.0      66.049483      61.005755     0.0      20.0
# num_subscribers   3678.0    3197.150625    9504.117010     0.0     111.0
# num_reviews       3678.0     156.259108     935.452044     0.0       4.0
# num_lectures      3678.0      40.108755      50.383346     0.0      15.0
# content_duration  3678.0       4.093750       6.054688     0.0       1.0
#
#                        50%        75%        max
# course_id         687917.0  961355.50  1282064.0
# price                 45.0      95.00      200.0
# num_subscribers      911.5    2546.00   268923.0
# num_reviews           18.0      67.00    27445.0
# num_lectures          25.0      45.75      779.0
# content_duration       2.0       4.50       78.5

# %%
# 자료형 데이터 타입 변경을 위한 nunique 값 갯수 찾기
# object -> category 화 하기 위해서 / 메모리 용량 save
course.level.nunique()
# Out:
# 4

# %%
course.subject.nunique()
# Out:
# 4

# %%
# 자료형 테이터 타입 변경
course['level'] = course['level'].astype('category')
course['subject'] = course['subject'].astype('category')
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int32
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int16
#  5   num_subscribers      3678 non-null   int32
#  6   num_reviews          3678 non-null   int16
#  7   num_lectures         3678 non-null   int16
#  8   level                3678 non-null   category
#  9   content_duration     3678 non-null   float16
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   category
# dtypes: bool(1), category(2), float16(1), int16(3), int32(2), object(3)
# memory usage: 155.0+ KB

# %%
type(course.published_timestamp[0])
# Out:
# str

# %%
course.head()
# Out:
#    course_id                                       course_title
# 0    1070968                 Ultimate Investment Banking Course  \
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200  \
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level
# 0             2147           23            51          All Levels  \
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
course['published_timestamp'] = (pd.to_datetime(course['published_timestamp'], format='%Y-%m-%dT%H:%M:%SZ', errors='raise'))

# %% [markdown]
# ## 2.2 데이터 메모리 최적화 결과

# %%
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int32
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int16
#  5   num_subscribers      3678 non-null   int32
#  6   num_reviews          3678 non-null   int16
#  7   num_lectures         3678 non-null   int16
#  8   level                3678 non-null   category
#  9   content_duration     3678 non-null   float16
#  10  published_timestamp  3678 non-null   datetime64[ns]
#  11  subject              3678 non-null   category
# dtypes: bool(1), category(2), datetime64[ns](1), float16(1), int16(3), int32(2), object(2)
# memory usage: 155.0+ KB

# %%
after_musage = course.memory_usage(deep=True).sum()

# %%
print(f'%.2f%%'%(after_musage*100/before_musage))
# Out:
# 50.71%

# %% [markdown]
# ## 결과
# ### 이전 대비 **_50.3%_** 로 메모리를 효과적으로 줄였습니다.
# <br>

# %% [markdown]
# # 3. 데이터 분석
# ---

# %% [markdown]
# ## 3.0 필요 정보 확인 및 추출

# %%
sns.countplot(x='subject', data=course)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %% [markdown]
# ## 가장 많은 강좌
# Business Finance와 Web Development가 가장 대중적인 강좌라고 할 수 있다.

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sns.countplot(y='level', data=course, order=course.level.value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='level'>

# %% [markdown]
# ## 주제별 총 리뷰 수 확인

# %%
data = {i:0 for i in set(course.subject.values)}
course_data = course[['subject', 'num_reviews']]
for index, row in course_data.iterrows():
    data[row.subject] += row.num_reviews
print(data)
df = pd.DataFrame.from_dict(data, orient='index', columns=['value'])
sns.barplot(y=df.index, x = 'value', data=df)
# Out:
# {'Web Development': 430025, 'Graphic Design': 37070, 'Business Finance': 75902, 'Musical Instruments': 31724}
# <Axes: xlabel='value'>

# %% [markdown]
# ## 강좌 가격에 따른 구독자 수

# %%
fig, ax = plt.subplots(figsize=(8,8))
course.plot.scatter(
    x = 'price',
    y = 'num_subscribers',
    alpha = .1,
    ax=ax
)
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %%
sns.relplot(
    x='subject',
    y='num_subscribers',
    data=course,
    hue='price',
    size='content_duration',
    alpha=.5,
    height=8
)

# %%
course_time = course.sort_values('published_timestamp')
course_grouped = course_time.groupby('subject').apply(lambda x: x.set_index('published_timestamp')['num_subscribers'].cumsum()).reset_index()
course_grouped = course_grouped.rename(columns={0: 'cumulate_subscribers'})

# %%
course_time
# Out:
#       course_id                                       course_title
# 2985       8324                           Javascript for Beginners  \
# 2491       8325            HTML Tutorial: HTML & CSS for Beginners
# 2701      11174                Become a Web Developer from Scratch
# 3082      11153     Learn jQuery: An In-depth Course For Beginners
# 2700      11475                   Become a Certified Web Developer
# ...         ...                                                ...
# 2645    1277924                            Angular 4 Front To Back
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
# 1108    1268616  Condor Broken Wing Butterfly Options Trading C...
# 462     1187084  Forex how traders beat the markest with little...
# 455     1282064  Cryptocurrency (BTC & ETH) Investment & Tradin...
#
#                                                     url  is_paid  price
# 2985        https://www.udemy.com/beginning-javascript/     True     20  \
# 2491                 https://www.udemy.com/learn-html5/     True     20
# 2701  https://www.udemy.com/how-to-become-a-web-deve...     True    120
# 3082                      https://www.udemy.com/jquery/     True     50
# 2700  https://www.udemy.com/become-a-certified-web-d...     True    100
# ...                                                 ...      ...    ...
# 2645     https://www.udemy.com/angular-4-front-to-back/     True     40
# 2405  https://www.udemy.com/abrsm-grade-iii-piano-cl...     True     20
# 1108  https://www.udemy.com/condor-broken-wing-butte...    False      0
# 462   https://www.udemy.com/forex-how-traders-beat-t...     True    100
# 455   https://www.udemy.com/cryptocurrency-btc-eth-i...     True     20
#
#       num_subscribers  num_reviews  num_lectures           level
# 2985             3697          195            48      All Levels  \
# 2491            12458          253            82      All Levels
# 2701            69186         2408           197      All Levels
# 3082             7014           95            62      All Levels
# 2700            26673         1090           185      All Levels
# ...               ...          ...           ...             ...
# 2645               44            0            68      All Levels
# 2405                0            0             5  Beginner Level
# 1108               16            0            15      All Levels
# 462                 0            0            16      All Levels
# 455                 0            0             7  Beginner Level
#
#       content_duration published_timestamp              subject
# 2985          3.000000 2011-07-09 05:43:31      Web Development
# 2491          4.000000 2011-09-09 15:28:59      Web Development
# 2701         27.500000 2011-11-19 21:51:20      Web Development
# 3082          4.500000 2011-11-29 01:29:11      Web Development
# 2700         12.000000 2011-12-20 15:29:25      Web Development
# ...                ...                 ...                  ...
# 2645          8.500000 2017-07-06 15:04:55      Web Development
# 2405          0.516602 2017-07-06 16:12:34  Musical Instruments
# 1108          1.500000 2017-07-06 19:47:16     Business Finance
# 462           1.000000 2017-07-06 21:16:13     Business Finance
# 455           2.500000 2017-07-06 21:46:30     Business Finance
#
# [3678 rows x 12 columns]

# %% [markdown]
# # 월당 구독자 증가 수

# %%
subject_data_names = ['Web Development', 'Business Finance', 'Graphic Design', 'Musical Instruments']
subject_datas = [
    (
        course_grouped[(course_grouped.subject == c) & (course_grouped.published_timestamp.between('2011-08', '2017-07'))]
        .set_index('published_timestamp')
        .resample('M')[['num_subscribers']]
        .sum()
    ) for c in subject_data_names
]

colors = ['red', 'blue', 'orange', 'green']

for i, subject_data in enumerate(subject_datas):
    plt.plot(subject_data, label=subject_data_names[i], color=colors[i])

# 그래프 제목, 범례, 축 레이블 설정
plt.title('Number of Subscribers by Subject')
plt.legend()
plt.xlabel('Published Timestamp')
plt.ylabel('Number of Subscribers')

# 그래프 출력
plt.show()

# %% [markdown]
# 2011년 8월부터 2017년 7월 이전까지의 월당 구독자 증감 수이다.
#
# 이를 통해 2015년 전후로 Web Development 과목의 구독자량이 급등한 것을 알 수 있다.
#
# 또한 동시에 Business Finance부분도 따라서 증가했다.
#
# 이 시기쯔음에 스타트업 붐이 일어 났고, 2014년 미국에서만 503억 달러 규모의 투자가 이루어 졌으며 2015년에는 이의 50%가 넘는 약 840억 달러의투자가 이뤄질것이라 전망되고 있었다(Ryu, 2015)
#
# 이 이후로도 꾸준하게 증가하는 구독자 수를 보면 아직까지도 스타트업 열풍이 크게 식지 않았고, 개발자와 금융 비지니스의 수요가 많다는 것을 알 수 있다.

# %% [markdown]
# # 주제별 시간에 따른 누적 구독자 수

# %%
sns.relplot(
    x='published_timestamp',
    y='num_subscribers',
    data=course_grouped,
    hue='subject',
    alpha=.1,
    height=6
)

# %% [markdown]
# ## 주제별 시간에 따른 누적 구독자수
# ### Web Development
# **Web Development**는 2011부터 누적 구독자 수 1위를 차지하고 있다. 최근까지도 구독자가 느는 속도가 가장 빠르다.
# ### Business Finance
# **Business Finance**는 2014년정도를 기준으로 2위였던 Musical Instruments를 제치고 2위를 차지했다.
# ### Graphic Design
# **Graphic Design**또한 2015년쯤 기준으로 3위였던 Musical Instruments를 제치고 3위를 달성했다.
# ### Musical Instruments
# **Busuness Finance**와 Graphic Design과 경쟁하던 Musical Instruments는 지속적으로 인기를 잃고 있다.

# %%
#course_time[['published_timestamp', 'subject', 'cumulate_subscribers']]
course.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
a = 0 if False else 1
print(a)
# Out:
# 1

# %%
course['log_subscribers'] = course['num_subscribers'].apply(lambda x: np.log10(x if x != 0 else 1))
course['log_reviews'] = course['num_reviews'].apply(lambda x: np.log10(x if x != 0 else 1))
course['published_str'] = course['published_timestamp'].apply(lambda x: int(datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S').timestamp()))

# %% [markdown]
# # 주제별 구독자 수에 따른 리뷰 수
# log함수로 보기 쉽게 만들었다.

# %%
g = sns.lmplot(
    data=course,
    x="log_subscribers",
    y="log_reviews", col="subject", hue="subject",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": .1}
)
g.set(xlim=(-1, 7), ylim=(-1, 7))

# %%
sns.lmplot(
    data=course,
    x="num_subscribers",
    y="num_reviews", col="subject", hue="subject",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": .1}
)

# %%
# stats.pearsonr(
#     course.num_reviews.values, 
#     course.num_subscribers.values
# )
# sns.heatmap(course.corr(), annot=True)
col = ['price', 'num_subscribers','num_reviews', 'content_duration']
subjects = ['Business Finance',
 'Graphic Design',
 'Musical Instruments',
 'Web Development']
# print(course.columns) # 
fig, ax = plt.subplots(ncols=2, nrows=2)
for sub_len in range(len(subjects)):
    sub=subjects[sub_len]
    sns.heatmap(course[course['subject'].isin([sub])][col].corr(), annot=True, ax=ax[sub_len//2,sub_len%2])
# sns.heatmap(course[course['subject'].isin([subjects[0]])][col].corr(), annot=True)

# %% [markdown]
# # 분석 결과
# 가격에 대한 상관계수는 대부분 높지 않았다.
#
# 그나마 가장 높은 것이 콘텐츠 길이라고 할 수 있다.

# %%
course.num_subscribers.describe().T
# Out:
# count      3678.000000
# mean       3197.150625
# std        9504.117010
# min           0.000000
# 25%         111.000000
# 50%         911.500000
# 75%        2546.000000
# max      268923.000000
# Name: num_subscribers, dtype: float64

# %%
np.log10(3)
# Out:
# 0.47712125471966244

# %%
course.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'log_subscribers',
#        'log_reviews', 'published_str'],
#       dtype='object')

# %%
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int32
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int16
#  5   num_subscribers      3678 non-null   int32
#  6   num_reviews          3678 non-null   int16
#  7   num_lectures         3678 non-null   int16
#  8   level                3678 non-null   category
#  9   content_duration     3678 non-null   float16
#  10  published_timestamp  3678 non-null   datetime64[ns]
#  11  subject              3678 non-null   category
#  12  log_subscribers      3678 non-null   float64
#  13  log_reviews          3678 non-null   float64
#  14  published_str        3678 non-null   int64
# dtypes: bool(1), category(2), datetime64[ns](1), float16(1), float64(2), int16(3), int32(2), int64(1), object(2)
# memory usage: 241.2+ KB

# %% [markdown]
# # 주제 별 강좌 지불 분석

# %% [markdown]
# ## 1.  모든 level 별 강좌 지불

# %%
course.describe().T
# Out:
#                       count                           mean
# course_id            3678.0                  675971.963295  \
# price                3678.0                      66.049483
# num_subscribers      3678.0                    3197.150625
# num_reviews          3678.0                     156.259108
# num_lectures         3678.0                      40.108755
# content_duration     3678.0                        4.09375
# published_timestamp    3678  2015-11-26 14:17:16.067699968
# log_subscribers      3678.0                       2.689503
# log_reviews          3678.0                       1.269897
# published_str        3678.0                1448515036.0677
#
#                                      min                         25%
# course_id                         8324.0                    407692.5  \
# price                                0.0                        20.0
# num_subscribers                      0.0                       111.0
# num_reviews                          0.0                         4.0
# num_lectures                         0.0                        15.0
# content_duration                     0.0                         1.0
# published_timestamp  2011-07-09 05:43:31  2015-03-16 19:01:45.500000
# log_subscribers                      0.0                    2.045323
# log_reviews                          0.0                     0.60206
# published_str               1310157811.0                1426500105.5
#
#                                      50%                            75%
# course_id                       687917.0                       961355.5  \
# price                               45.0                           95.0
# num_subscribers                    911.5                         2546.0
# num_reviews                         18.0                           67.0
# num_lectures                        25.0                          45.75
# content_duration                     2.0                            4.5
# published_timestamp  2016-01-27 18:10:50  2016-10-29 21:19:39.750000128
# log_subscribers                 2.959757                       3.405858
# log_reviews                     1.255273                       1.826075
# published_str               1453885850.0                  1477743579.75
#
#                                      max              std
# course_id                      1282064.0     343273.15604
# price                              200.0        61.005755
# num_subscribers                 268923.0       9504.11701
# num_reviews                      27445.0       935.452044
# num_lectures                       779.0        50.383346
# content_duration                    78.5         6.054688
# published_timestamp  2017-07-06 21:46:30              NaN
# log_subscribers                 5.429628         1.055564
# log_reviews                     4.438463         0.834861
# published_str               1499345190.0  35876383.926989

# %% [markdown]
# # 분석
# 주제와 레벨별 가격에 따른 강좌 개수의 통계

# %%
{
    sns.FacetGrid(course, col = 'subject', row = 'level', palette="tab20c")
        .map(sns.histplot, 'price')
}
# Out:
# {<seaborn.axisgrid.FacetGrid at 0x1850605feb0>}

# %%
sns.lmplot(x = 'num_lectures', y = 'price', data = course, hue = 'subject').set(ylim=(None, 250))

# %% [markdown]
# # Level에 따른 가격 차이를 주제와 비교
# 가격의 최대 값은 차이가 없다.
#
# Level이 올라갈 수록 높은 가격이 요구된다.
#
# 또한 Expert Level에서는 무료 강의가 없는 것을 볼 수 있다.

# %%
sns.boxplot(data = course, x='level', y='price', hue='subject', order=['All Levels', 'Beginner Level', 'Intermediate Level', 'Expert Level'])
# Out:
# <Axes: xlabel='level', ylabel='price'>

# %% [markdown]
# # 주제별 가격에 따른 리뷰수
# 낮은 상관관계를 보인다.

# %%
sns.lmplot(
    data=course,
    x="price",
    y="log_reviews", col="subject", hue="subject",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": .1}
)

# %% [markdown]
# # 가격별 강좌 길이

# %%
sns.lmplot(
    data=course,
    x="price",
    y="content_duration", col="subject", hue="subject",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": .1}
)

# %% [markdown]
# # 수익 column 추가

# %%
course['earning'] = course['price']*course['num_subscribers']

# %%
# fig, ax = plt.subplots(figsize=(10, 10))
sns.lmplot(data=course, x='earning', y='num_subscribers', scatter_kws={"s": 20, "alpha": .2}, hue='subject', height=10)

# %% [markdown]
# # 수익
#
# Web Development 분야에서 가장 많은 수익이 난다.

# %%
sns.barplot(x='level', y='earning', data=course)
# Out:
# <Axes: xlabel='level', ylabel='earning'>

# %%
course['earning']
# Out:
# 0       429400
# 1       209400
# 2        97830
# 3       232845
# 4       255200
#          ...
# 3673    104000
# 3674      7650
# 3675     20520
# 3676     15000
# 3677     40545
# Name: earning, Length: 3678, dtype: int32

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.histplot(x='price',
              data=course, hue='subject', binwidth=5,
            ax=ax
         )
# Out:
# <Axes: xlabel='price', ylabel='Count'>
